# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import time 

# Turning off wanring messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                                  City      Lat       Lng  Max Temp  \
# 0        0                              ust'-kut  56.7938  105.7672     10.79
# 1        1                              bilibino  68.0546  166.4372      0.39
# 2        2  palikir - national government center   6.9248  158.1611     28.30
# 3        3                           meadow lake  34.8014 -106.5436     19.21
# 4        4                          arkhangel'sk  64.5401   40.5433     18.35
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        59          44        1.89      RU  1686834280
# 1        69           9        2.41      RU  1686834280
# 2        77         100        5.78      FM  1686834281
# 3        27           0        3.65      US  1686834281
# 4        45           9        4.72      RU  1686834025

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    x='Lng',
    y='Lat',
    c='Max Temp',
    cmap='coolwarm',
    hover_cols=['City'],
    size=85,
    geo = True,
    frame_width = 600,
    frame_height = 400,
    title='City Temperature Distribution'
)

# Display the map
map_plot
# Out:
# :Points   [Lng,Lat]   (Max Temp,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_df = city_data_df.loc[(city_data_df['Max Temp'] < 30) & (city_data_df['Humidity'] <= 101) & (city_data_df['Cloudiness'] == 0) & (city_data_df['Wind Speed'] < 5)]

# Drop any rows with null values
narrowed_city_df = narrowed_city_df.dropna()

# Display sample data
narrowed_city_df.head()
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3         3    meadow lake  34.8014 -106.5436     19.21        27           0
# 17       17         sangju  36.4153  128.1606     19.77        86           0
# 28       28     fort bragg  35.1390  -79.0060     24.55        79           0
# 31       31       pavlodar  52.3000   76.9500     24.89        22           0
# 50       50  alice springs -23.7000  133.8833      9.56        46           0
#
#     Wind Speed Country        Date
# 3         3.65      US  1686834281
# 17        0.58      KR  1686834157
# 28        2.06      US  1686834284
# 31        2.00      KZ  1686834017
# 50        3.09      AU  1686834288

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df
hotel_df = narrowed_city_df.loc[narrowed_city_df['Humidity'] <= 101, ['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 3     meadow lake      US  34.8014 -106.5436        27
# 17         sangju      KR  36.4153  128.1606        86
# 28     fort bragg      US  35.1390  -79.0060        79
# 31       pavlodar      KZ  52.3000   76.9500        22
# 50  alice springs      AU -23.7000  133.8833        46

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
print(geoapify_key)
# Out:
# 82c5af3255d8440d81b11727c79e7954

# %%
params= {}

# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    time.sleep(2)
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = f"https://api.geoapify.com/v2/places" 

    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index,"Hotel Name"] = name_address["features"][0]["properties"]["name"] 
    except (KeyError, IndexError):
         # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# meadow lake - nearest hotel: No hotel found
# sangju - nearest hotel: 상주관광호텔
# fort bragg - nearest hotel: Airborne Inn Lodging
# pavlodar - nearest hotel: Север
# alice springs - nearest hotel: Aurora Alice Springs
# armidale - nearest hotel: Lindsay House
# brookings - nearest hotel: Quality Inn
# newman - nearest hotel: No hotel found
# sidi bel abbes - nearest hotel: hotel palace
# vilyuchinsk - nearest hotel: Победа
# westport - nearest hotel: Norwalk Inn and Conference Center
# anadyr - nearest hotel: Гостевой дом
# malvan - nearest hotel: Hotel Silver Sand
# sinan - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# hamilton - nearest hotel: North Vista Manor
# marondera - nearest hotel: No hotel found
# salinopolis - nearest hotel: Hotel Salinópolis
# broken hill - nearest hotel: Ibis Styles
# thompson - nearest hotel: Thompson Inn
# silver city - nearest hotel: Murray Hotel
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# coquimbo - nearest hotel: Hotel Iberia
# valls - nearest hotel: Hotel Class Valls
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# ondjiva - nearest hotel: Águia Verde Hotel
# arlington - nearest hotel: Parkway Inn
# estacion santa engracia - nearest hotel: No hotel found
# lubango - nearest hotel: Novo Hotel
# kas - nearest hotel: KEKOVA OTEL
# luena - nearest hotel: No hotel found
# skelleftea - nearest hotel: Hotel Victoria
# ambalavao - nearest hotel: RAVORAVO HOTEL
# winchester - nearest hotel: Royal Hotel
# laguna - nearest hotel: Holiday Inn Express & Suites
# jamestown - nearest hotel: DoubleTree Jamestown
# tsiombe - nearest hotel: No hotel found
# maxixe - nearest hotel: Hotel Herry
# waat - nearest hotel: Hotel Montana
# belton - nearest hotel: Hampton Inn & Suites
# inhambane - nearest hotel: Hotel de Inhambane
# urzhar - nearest hotel: Sharikan
# port macquarie - nearest hotel: The Observatory
# cheremushki - nearest hotel: Борус
# maputo - nearest hotel: Mozaika
# uiju - nearest hotel: No hotel found
# correntina - nearest hotel: Pousada Silva
# tolanaro - nearest hotel: Hôtel Mahavokey
# sao felix do xingu - nearest hotel: Hotel Terraço
# colonia - nearest hotel: Wasserturm Hotel Cologne
# somerset - nearest hotel: Hilton Garden Inn Bridgewater
# truro - nearest hotel: Mannings Hotel
# yatou - nearest hotel: No hotel found
# belyy yar - nearest hotel: No hotel found
# grand island - nearest hotel: Grand Island Travelodge
# tambopata - nearest hotel: No hotel found
# fort st. john - nearest hotel: Fort St. John Motor Inn
#                         City Country      Lat       Lng  Humidity  \
# 3                meadow lake      US  34.8014 -106.5436        27
# 17                    sangju      KR  36.4153  128.1606        86
# 28                fort bragg      US  35.1390  -79.0060        79
# 31                  pavlodar      KZ  52.3000   76.9500        22
# 50             alice springs      AU -23.7000  133.8833        46
# 87                  armidale      AU -30.5167  151.6500        91
# 115                brookings      US  44.3114  -96.7984        77
# 118                   newman      US  37.3138 -121.0208        84
# 126           sidi bel abbes      DZ  35.1899   -0.6309        23
# 134              vilyuchinsk      RU  52.9306  158.4028        80
# 152                 westport      US  41.1415  -73.3579        70
# 159                   anadyr      RU  64.7500  177.4833        80
# 162                   malvan      IN  16.0667   73.4667        78
# 171                    sinan      KR  34.8262  126.1086        79
# 173            haiku-pauwela      US  20.9219 -156.3051        83
# 189                 hamilton      US  39.1834  -84.5333        86
# 218                marondera      ZW -18.1853   31.5519        11
# 226              salinopolis      BR  -0.6136  -47.3561        81
# 232              broken hill      AU -31.9500  141.4333        59
# 240                 thompson      CA  55.7435  -97.8558        41
# 250              silver city      US  32.7701 -108.2803        35
# 252               kingscliff      AU -28.2667  153.5667        87
# 270                 coquimbo      CL -29.9533  -71.3436        44
# 275                    valls      ES  41.2861    1.2499        46
# 285         kill devil hills      US  36.0307  -75.6760        81
# 289                  ondjiva      AO -17.0667   15.7333         8
# 294                arlington      US  32.7357  -97.1081        80
# 302  estacion santa engracia      MX  24.0159  -99.2015        52
# 304                  lubango      AO -14.9172   13.4925        18
# 315                      kas      TR  36.2018   29.6377        52
# 317                    luena      AO -11.7833   19.9167        15
# 324               skelleftea      SE  64.7507   20.9528        34
# 329                ambalavao      MG -21.8333   46.9333        39
# 335               winchester      GB  51.0651   -1.3187        36
# 338                   laguna      US  38.4210 -121.4238        83
# 341                jamestown      US  42.0970  -79.2353        86
# 350                  tsiombe      MG -25.3000   45.4833        23
# 352                   maxixe      MZ -23.8597   35.3472        25
# 355                     waat      DE  51.1454    6.4958        36
# 368                   belton      US  38.8120  -94.5319        83
# 377                inhambane      MZ -23.8650   35.3833        28
# 384                   urzhar      KZ  47.0930   81.6294        24
# 388           port macquarie      AU -31.4333  152.9167        75
# 390              cheremushki      RU  52.8356   91.3944        65
# 426                   maputo      MZ -25.9653   32.5892        74
# 460                     uiju      KP  40.1994  124.5317        86
# 461               correntina      BR -13.3433  -44.6367        46
# 462                 tolanaro      MG -25.0319   46.9987        54
# 472       sao felix do xingu      BR  -6.6447  -51.9950        53
# 475                  colonia      DE  50.9333    6.9500        28
# 504                 somerset      US  40.5668  -74.5496        69
# 508                    truro      GB  50.2653   -5.0544        73
# 509                    yatou      CN  37.1500  122.3833        82
# 513                belyy yar      RU  53.6039   91.3903        30
# 524             grand island      US  40.9250  -98.3420        70
# 556                tambopata      PE -12.7333  -69.1833        63
# 557            fort st. john      CA  56.2499 -120.8529       100
#
#                             Hotel Name
# 3                       No hotel found
# 17                              상주관광호텔
# 28                Airborne Inn Lodging
# 31                               Север
# 50                Aurora Alice Springs
# 87                       Lindsay House
# 115                        Quality Inn
# 118                     No hotel found
# 126                       hotel palace
# 134                             Победа
# 152  Norwalk Inn and Conference Center
# 159                       Гостевой дом
# 162                  Hotel Silver Sand
# 171                     No hotel found
# 173           Inn At Mama's Fish House
# 189                  North Vista Manor
# 218                     No hotel found
# 226                  Hotel Salinópolis
# 232                        Ibis Styles
# 240                       Thompson Inn
# 250                       Murray Hotel
# 252             Kingscliff Beach Hotel
# 270                       Hotel Iberia
# 275                  Hotel Class Valls
# 285          Mariner Days Inn & Suites
# 289                  Águia Verde Hotel
# 294                        Parkway Inn
# 302                     No hotel found
# 304                         Novo Hotel
# 315                        KEKOVA OTEL
# 317                     No hotel found
# 324                     Hotel Victoria
# 329                     RAVORAVO HOTEL
# 335                        Royal Hotel
# 338       Holiday Inn Express & Suites
# 341               DoubleTree Jamestown
# 350                     No hotel found
# 352                        Hotel Herry
# 355                      Hotel Montana
# 368               Hampton Inn & Suites
# 377                 Hotel de Inhambane
# 384                           Sharikan
# 388                    The Observatory
# 390                              Борус
# 426                            Mozaika
# 460                     No hotel found
# 461                      Pousada Silva
# 462                    Hôtel Mahavokey
# 472                      Hotel Terraço
# 475           Wasserturm Hotel Cologne
# 504      Hilton Garden Inn Bridgewater
# 508                     Mannings Hotel
# 509                     No hotel found
# 513                     No hotel found
# 524            Grand Island Travelodge
# 556                     No hotel found
# 557            Fort St. John Motor Inn

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.scatter(
    x="Lng",
    y="Lat",
    c="Humidity",
    cmap="viridis",
    colorbar=True,
    hover_cols=["City", "Country", "Hotel Name", "Humidity"],
    title="Hotel Locations",
    xlabel="Longitude",
    ylabel="Latitude",
    frame_width=600,
    frame_height=400,
)

# Display the map
map_plot
